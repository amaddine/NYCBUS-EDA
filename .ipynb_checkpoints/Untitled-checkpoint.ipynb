# %%
import pandas as pd 
import numpy as np

# %%
data_frame = pd.read_csv('clean.csv')
# Out:
# /Users/abhimaddineni/miniconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (18,22) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data_frame.head()
# Out:
#    Unnamed: 0 School_Year  Busbreakdown_ID           Run_Type Bus_No  \
# 0           0   2015-2016          1212699  Special Ed AM Run  48186
# 1           1   2015-2016          1212700  Special Ed AM Run   2518
# 2           2   2015-2016          1212701  Special Ed AM Run    235
# 3           3   2015-2016          1212703  Special Ed AM Run   2102
# 4           4   2015-2016          1212704  Special Ed AM Run  48162
#
#   Route_Number              Reason Schools_Serviced          Occurred_On  \
# 0         N758               Other            75485  2015-09-02T06:27:00
# 1         L530  Mechanical Problem            21854  2015-09-02T06:24:00
# 2         K168               Other            18366  2015-09-02T06:45:00
# 3         K216               Other            21501  2015-09-02T06:55:00
# 4         N861  Mechanical Problem            75485  2015-09-02T06:55:00
#
#             Created_On        ...         Number_Of_Students_On_The_Bus  \
# ...

# %%
def clean_up(x):
    if x == 'Yes':
        x = True
    elif x == 'No':
        x = False

# %%
data_frame['Has_Contractor_Notified_Schools_bool'] = data_frame['Has_Contractor_Notified_Schools'].map(lambda x: clean_up(x))
data_frame['Has_Contractor_Notified_Parents_bool'] = data_frame['Has_Contractor_Notified_Parents'].map(lambda x: clean_up(x))
